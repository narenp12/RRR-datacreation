# %% [markdown]
# # Notebook for querying and creating arXiv dataset (later)

# %%
import paperscraper
import numpy as np
import pandas as pd
import plotly.express as px

# %%
from paperscraper.get_dumps import arxiv
arxiv(start_date='2002-01-01', end_date=None) # scrapes all metadata from 2002 until today.
# Out:
# Fetching 2002-02-04:   0%|          | 34/8502 [01:46<6:18:25,  2.68s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 from paperscraper.get_dumps import arxiv
# ----> 2 arxiv(start_date='2002-01-01', end_date=None) # scrapes all metadata from 2024 until today.
#
# File ~/Documents/GitHub/RRR-datacreation/.pixi/envs/default/lib/python3.12/site-packages/paperscraper/get_dumps/arxiv.py:63, in arxiv(start_date, end_date, save_path)
#      61 query = f"submittedDate:[{current_date.strftime('%Y%m%d0000')} TO {next_date.strftime('%Y%m%d0000')}]"
#      62 try:
# ---> 63     papers = get_arxiv_papers_api(
#      64         query=query,
#      65         fields=["title", "authors", "date", "abstract", "journal", "doi"],
#      66         verbose=False,
#      67     )
#      68     if not papers.empty:
# ...
